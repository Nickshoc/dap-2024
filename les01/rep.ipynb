# %% [markdown]
# <a href="https://colab.research.google.com/github/Nickshoc/dap-2024/blob/main/rep.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Отчёт по лабораторной работе 1
#
# ## Задание
#
# 1. Создали учетную запись в сервисе GitHub
# 2. Выполнили форк репозитория https://github.com/chebotarevsa/dap-2024
# 3. Создали учетную запись в Google Colab
# 4. Настроили интеграцию Google Colab и GitHub
# 5. Создали в Google Colab отчет о выполненой работе в виде файла rep.ipynb.
# 6. Сохранили отчет в ваш репозиторий github в директории ./les01
# 7. Создали pull request в репозиторий https://github.com/chebotarevsa/dap-2024.
#
# ## Ответы на вопросы
#
# 1.
#   * Code — блоки, в которых содержится исполняемый код. Например, с их помощью можно написать выражение на Python, запустить его и сразу же увидеть результат ниже.
#
#   * Markdown — ячейки для форматирования текста. Если хотите добавить к коду подробное объяснение, то используйте этот блок.
#
#   * Raw — «сырые» данные, которые используют для настройки сложных сценариев импорта и визуализации данных.
#
# 2.
# * Элемент 1
# * Элемент 2
#     + Элемент 2 1
#     + Элемент 2 2
#         + Элемент 2 2 1
#         + Элемент 2 2 2
# * Элемент 3
#
# 3. Чтобы параграф отобразился как цитата, нужно поставить перед ним закрывающую угловую скобку >.
#
# 4. В Markdown есть несколько способов выделить исходный код:
#
#   * Если надо отобразить фрагмент кода внутри строки с каким-то текстом, нужно с двух сторон выделить этот код одним или несколькими обратными апострофами (`; их ещё называют бэктиками).
#   * Чтобы выделить фрагмент из нескольких строк, нужно с двух сторон выделить его тремя обратными апострофами.
#   * Также перед фрагментом кода можно поставить табуляцию или четыре пробела, при этом предыдущая строка должна быть пустой.
#
# 5. 6 уровней.
#
# 6.
#
#  * **Определение проблемы или выдвижение идей**
#
#  * **Извлечение или сбор данных**
#
#  * **Подготовка данных**
#
#  * **Исследование и визуализация данных**
#
#  * **Предсказательная модель**
#
#  * **Проверка модели** - на этом этапе производиться проверка модели, построенной на основе начальных данных. Он важен, потому что позволяет узнать достоверность данных, созданных моделью, сравнив их с реальной системой. Как правило, при использовании данных для построения модели вы будете воспринимать их как тренировочный набор данных, а для проверки — как валидационный набор данных.
#
#  * **Развертывание**
#
# 7.
# * **Структурированные данные** - это тип данных, при котором последние упорядочены в вертикальные столбцы (поля) и горизонтальные строки (записи или наблюдения). Примером таких данных являются данные в реляционных базах и электронных таблицах. Структурированные данные зависят от модели данных, которая представляет собой определенную структуру, содержательного смысла данных и часто от способа обработки данных. Сюда входит идентификация типа данных (целое число, число с плавающей точкой, строка и т.д.) и ограничения, накладываемые на данные, например, количество символов, максимальное и минимальное значения, или ограничение на определенный набор значений.
#
# * **Неструктурированные данные**
#
# * **Полуструктурированные данные**
#
# 8. Jupyter Notebook - интерактивный блокнот, первоначально являвшийся веб-реализацией и развитием IPython, ставший самостоятельным проектом, ориентированным на работу со множеством сред выполнения.
#
# 9.
# * Простота и читаемость кода
# * Обширная библиотека инструментов
# * Активное сообщество и поддержка
# * Кроссплатформенность
# * Гибкость и расширяемость
#
# 10. Jupyter Notebook не является обязательным инструментом для анализа данных, но подходит для работы с данными благодаря интерактивности и возможности визуализации результатов.
